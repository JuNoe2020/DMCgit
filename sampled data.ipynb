# %%
import os
import json
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize

# %%
def load_df(csv_path="data/train.csv", nrows=None):
    JSON_COLUMNS = ['device', 'geoNetwork', 'totals', 'trafficSource']
    
    df = pd.read_csv(csv_path, 
                     converters={column: json.loads for column in JSON_COLUMNS}, 
                     dtype={'fullVisitorId': 'str'}, # Important!!
                     nrows=nrows)
    
    for column in JSON_COLUMNS:
        column_as_df = json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
    print(f"Loaded {os.path.basename(csv_path)}. Shape: {df.shape}")
    return df

# %%
# %%time
train_df = load_df()
# Out:
# <ipython-input-22-0d6221d7d2c4>:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   column_as_df = json_normalize(df[column])
# Loaded train.csv. Shape: (903653, 55)
# Wall time: 1min 38s

# %%
sampled_df = train_df.sample(frac=0.05, # fraction of axis items to return.
          random_state=1004)

sampled_df
# Out:
#        channelGrouping      date        fullVisitorId  \
# 606162          Social  20161012  8328142757107731335
# 638960  Organic Search  20170604  2820865792641638468
# 104393  Organic Search  20170704  9391790015379420498
# 537901          Direct  20160801  0463567805880031157
# 892768  Organic Search  20170324  3286846428786104447
# ...                ...       ...                  ...
# 115857  Organic Search  20160824  6467467514016614847
# 775671     Paid Search  20170103  8760976577062696927
# 252676          Direct  20170426  9950452748220930180
# 821302        Referral  20170628  7306383193016987879
# 655566          Social  20161206  1790575376744285245
#
#                              sessionId  socialEngagementType     visitId  \
# 606162  8328142757107731335_1476339305  Not Socially Engaged  1476339305
# 638960  2820865792641638468_1496598344  Not Socially Engaged  1496598344
# 104393  9391790015379420498_1499182190  Not Socially Engaged  1499182190
# 537901  0463567805880031157_1470043264  Not Socially Engaged  1470043264
# 892768  3286846428786104447_1490390553  Not Socially Engaged  1490390553
# ...                                ...                   ...         ...
# 115857  6467467514016614847_1472033936  Not Socially Engaged  1472033936
# 775671  8760976577062696927_1483467163  Not Socially Engaged  1483467163
# 252676  9950452748220930180_1493264844  Not Socially Engaged  1493264844
# 821302  7306383193016987879_1498639307  Not Socially Engaged  1498639307
# 655566  1790575376744285245_1481081357  Not Socially Engaged  1481081357
#
#         visitNumber  visitStartTime   device.browser  \
# 606162            2      1476339305           Chrome
# 638960            1      1496598344  Safari (in-app)
# 104393            1      1499182190           Chrome
# 537901            1      1470043264           Safari
# 892768            1      1490390553           Chrome
# ...             ...             ...              ...
# 115857            1      1472033936           Chrome
# 775671            1      1483467163           Chrome
# 252676            1      1493264844           Chrome
# 821302            1      1498639307           Chrome
# 655566            1      1481081357           Safari
#
#                 device.browserVersion  ...  \
# 606162  not available in demo dataset  ...
# 638960  not available in demo dataset  ...
# 104393  not available in demo dataset  ...
# 537901  not available in demo dataset  ...
# 892768  not available in demo dataset  ...
# ...                               ...  ...
# 115857  not available in demo dataset  ...
# 775671  not available in demo dataset  ...
# 252676  not available in demo dataset  ...
# 821302  not available in demo dataset  ...
# 655566  not available in demo dataset  ...
#
#        trafficSource.adwordsClickInfo.criteriaParameters  \
# 606162                     not available in demo dataset
# 638960                     not available in demo dataset
# 104393                     not available in demo dataset
# 537901                     not available in demo dataset
# 892768                     not available in demo dataset
# ...                                                  ...
# 115857                     not available in demo dataset
# 775671                     not available in demo dataset
# 252676                     not available in demo dataset
# 821302                     not available in demo dataset
# 655566                     not available in demo dataset
#
#        trafficSource.isTrueDirect trafficSource.referralPath  \
# 606162                       True              /yt/about/tr/
# 638960                        NaN                        NaN
# 104393                        NaN                        NaN
# 537901                       True                        NaN
# 892768                        NaN                        NaN
# ...                           ...                        ...
# 115857                        NaN                        NaN
# 775671                        NaN                        NaN
# 252676                       True                        NaN
# 821302                        NaN            /analytics/web/
# 655566                        NaN                 /yt/about/
#
#         trafficSource.adwordsClickInfo.page  \
# 606162                                  NaN
# 638960                                  NaN
# 104393                                  NaN
# 537901                                  NaN
# 892768                                  NaN
# ...                                     ...
# 115857                                  NaN
# 775671                                    1
# 252676                                  NaN
# 821302                                  NaN
# 655566                                  NaN
#
#        trafficSource.adwordsClickInfo.slot  \
# 606162                                 NaN
# 638960                                 NaN
# 104393                                 NaN
# 537901                                 NaN
# 892768                                 NaN
# ...                                    ...
# 115857                                 NaN
# 775671                                 Top
# 252676                                 NaN
# 821302                                 NaN
# 655566                                 NaN
#
#                      trafficSource.adwordsClickInfo.gclId  \
# 606162                                                NaN
# 638960                                                NaN
# 104393                                                NaN
# 537901                                                NaN
# 892768                                                NaN
# ...                                                   ...
# 115857                                                NaN
# 775671  Cj0KEQiAtK3DBRCBxt-Yxduq5p4BEiQAbFiaPeDO6pEevf...
# 252676                                                NaN
# 821302                                                NaN
# 655566                                                NaN
#
#        trafficSource.adwordsClickInfo.adNetworkType  \
# 606162                                          NaN
# 638960                                          NaN
# 104393                                          NaN
# 537901                                          NaN
# 892768                                          NaN
# ...                                             ...
# 115857                                          NaN
# 775671                                Google Search
# 252676                                          NaN
# 821302                                          NaN
# 655566                                          NaN
#
#        trafficSource.adwordsClickInfo.isVideoAd trafficSource.adContent  \
# 606162                                      NaN                     NaN
# 638960                                      NaN                     NaN
# 104393                                      NaN                     NaN
# 537901                                      NaN                     NaN
# 892768                                      NaN                     NaN
# ...                                         ...                     ...
# 115857                                      NaN                     NaN
# 775671                                    False                     NaN
# 252676                                      NaN                     NaN
# 821302                                      NaN                     NaN
# 655566                                      NaN                     NaN
#
#        trafficSource.campaignCode
# 606162                        NaN
# 638960                        NaN
# 104393                        NaN
# 537901                        NaN
# 892768                        NaN
# ...                           ...
# 115857                        NaN
# 775671                        NaN
# 252676                        NaN
# 821302                        NaN
# 655566                        NaN
#
# [45183 rows x 55 columns]

# %%
sampled_df.to_csv()
